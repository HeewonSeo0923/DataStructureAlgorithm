# %%
# 1부터 100까지 반복하여 출력하기
for i in range (1, 101):
    print(f'i = {i:4}    id(i)={id(i)}')
# Out:
# i =    1    id(i)=1903183751472
# i =    2    id(i)=1903183751504
# i =    3    id(i)=1903183751536
# i =    4    id(i)=1903183751568
# i =    5    id(i)=1903183751600
# i =    6    id(i)=1903183751632
# i =    7    id(i)=1903183751664
# i =    8    id(i)=1903183751696
# i =    9    id(i)=1903183751728
# i =   10    id(i)=1903183751760
# i =   11    id(i)=1903183751792
# i =   12    id(i)=1903183751824
# i =   13    id(i)=1903183751856
# i =   14    id(i)=1903183751888
# i =   15    id(i)=1903183751920
# i =   16    id(i)=1903183751952
# i =   17    id(i)=1903183751984
# i =   18    id(i)=1903183752016
# i =   19    id(i)=1903183752048
# i =   20    id(i)=1903183752080
# i =   21    id(i)=1903183752112
# i =   22    id(i)=1903183752144
# i =   23    id(i)=1903183752176
# i =   24    id(i)=1903183752208
# i =   25    id(i)=1903183752240
# i =   26    id(i)=1903183752272
# i =   27    id(i)=1903183752304
# i =   28    id(i)=1903183752336
# i =   29    id(i)=1903183752368
# ...
